# %% [markdown]
# # **EXPERIMENT 3: PYTHON DATA ANALYSIS (PANDAS)**

# %% [markdown]
# ***Made by: James Marty Jacob | 2ECE-B***

# %% [markdown]
# Initial Conditions:

# %%
import pandas as pd

# %%
cars = pd.read_csv('cars.csv')

# %% [markdown]
# **A. Positional and Label-based Slicing**

# %%
cars
# Out:
#                   Model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# *a.*

# %%
#Part A.a:

print("Cars Dataset Shape:", cars.shape) #prints the datas shape (rows, columns)

print("Cars Column Names:", cars.columns.tolist()) # prints the datas column names
# Out:
# Cars Dataset Shape: (32, 12)
# Cars Column Names: ['Model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

# %% [markdown]
# *b.*

# %%
#Part A.b

cars_6_to_10 = cars.iloc[5:10] #Includes only rows 6 to 10

cars_6_to_10 #Checking
# Out:
#         Model   mpg  cyl   disp   hp  drat    wt   qsec  vs  am  gear  carb
# 5     Valiant  18.1    6  225.0  105  2.76  3.46  20.22   1   0     3     1
# 6  Duster 360  14.3    8  360.0  245  3.21  3.57  15.84   0   0     3     4
# 7   Merc 240D  24.4    4  146.7   62  3.69  3.19  20.00   1   0     4     2
# 8    Merc 230  22.8    4  140.8   95  3.92  3.15  22.90   1   0     4     2
# 9    Merc 280  19.2    6  167.6  123  3.92  3.44  18.30   1   0     4     4

# %% [markdown]
# *c.*

# %%
#Part A.c

subset_c = cars_6_to_10[['Model', 'mpg', 'cyl', 'hp', 'gear']] #Includes only the specific categories stated

display(subset_c)
# Out:
#         Model   mpg  cyl   hp  gear
# 5     Valiant  18.1    6  105     3
# 6  Duster 360  14.3    8  245     3
# 7   Merc 240D  24.4    4   62     4
# 8    Merc 230  22.8    4   95     4
# 9    Merc 280  19.2    6  123     4

# %% [markdown]
# **B. Model Lookup**

# %% [markdown]
# *a.*

# %%
toyota = cars[cars['Model'] == 'Toyota Corolla'] #Looks for the model "toyota"

# %%
display(toyota) #Displays only the toyota row
# Out:
#              Model   mpg  cyl  disp  hp  drat     wt  qsec  vs  am  gear  carb
# 19  Toyota Corolla  33.9    4  71.1  65  4.22  1.835  19.9   1   1     4     1

# %% [markdown]
# *b.*

# %%
pontiac_col = ['Model', 'mpg', 'hp', 'wt'] #Obtains only the columns specified

# %%
pontiac = cars[cars['Model'] == 'Pontiac Firebird'][pontiac_col]

# %%
display(pontiac) #Displays Pontiac Firebird row
# Out:
#                Model   mpg   hp     wt
# 24  Pontiac Firebird  19.2  175  3.845

# %% [markdown]
# **C. Multi-Model Subsetting**

# %%
target_models = ['Datsun 710', 'Lotus Europa', 'Ferrari Dino'] #Obtains only the models specified
target_cols = ['Model', 'mpg', 'cyl', 'hp', 'gear'] #Obtains only the columns specified

# %%
selected_cars = cars[cars['Model'].isin(target_models)][target_cols]

# %%
display(selected_cars) #Displays the list specified
# Out:
#            Model   mpg  cyl   hp  gear
# 2     Datsun 710  22.8    4   93     4
# 27  Lotus Europa  30.4    4  113     5
# 29  Ferrari Dino  19.7    6  175     5

# %%
print("Shape of selected_cars:", selected_cars.shape) #Displays the shape of selected_cars
# Out:
# Shape of selected_cars: (3, 5)

# %% [markdown]
# *CHECKING*

# %%
if selected_cars.shape == (3, 5):
  print("Check passed: Selected_cars has exactly 3 rows and 5 columns")
else:
  print("Check Failed.") #Checks the rows and colums if correct
# Out:
# Check passed: Selected_cars has exactly 3 rows and 5 columns
